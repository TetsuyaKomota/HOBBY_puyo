# %% [markdown]
# ## 20210212 メモ

# %% [markdown]
# ### 普段の練習方法
# - 特に形や手順が悪かったと感じた試合について，
#     1. 1手ずつリプレイし，特に悪かった手を確認(なぜ悪かったか言葉にする)
#     1. 思考時間が十分にあるならどこに置いていたか，とこぷよ形式でシミュレーション

# %% [markdown]
# ### 具体例
# - 以下の試合を例に実践
#     - [Youtube](https://www.youtube.com/watch?v=NBa65veyaR4&t=638&ab_channel=%E3%82%B3%E3%83%A2%E3%82%BF)

# %%
import IPython.display

IPython.display.YouTubeVideo("NBa65veyaR4", start=638)

# %% [markdown]
# #### 1手ずつリプレイし，特に悪かった手を確認(なぜ悪かったか言葉にする)
# - 3手目まで
# ![image001.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image001.png)

# %% [markdown]
# - 4手目は悪手というほどではないが，ほかの選択肢もありそう (2. で再考)
# ![image002.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image002.png)

# %% [markdown]
# - 5手目がかなり悪手だと思う
#     - 新GTRの受け入れが結構制限される
#     - ネクストで赤紫が見えているので，赤は連鎖尾側に使いたい気がする
#     - 特に理由なく1列目を高くしたいというだけで不要なちぎりが発生している
# ![image003.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image003.png)
# - 以下のような置き方のほうがよさそう
#
# |置き方例|こっちのほうがいいと思う理由|
# |:-|:-|
# |![puyo001.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo001.png)|DT砲を見据えて，1列目に緑の受けを作る．またちぎりが発生しない|
# |![puyo002.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo002.png)|連鎖尾の紫->赤を見据える．また折り返し側の色を保留する|
# |![puyo003.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo003.png)|ネクネクの赤ダブを折り返しに使い，青->赤->緑の理想形を見据える|

# %% [markdown]
# - 7手目は，5手目で折り返しと連鎖尾に赤が分散してしまった状態における最悪の選択に見える
#     - 1列目に不用意に置いてしまった赤を3連結にして早めに見通しをつけたい
#     - 連鎖尾側はこのまま進めると赤の仕掛けぷよが3連結になって暴発とか事故につながりそう
#
# ![image004.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image004.png)

# %% [markdown]
# - 9手目は紫の4連結に無駄にこだわってちぎっているが6列目の紫は結局最後までごみぷよだったので素直に4,5列目 or 5列目縦置きでよさそう
# ![image005.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image005.png)
#
# |置き方例|こっちのほうがいいと思う理由|
# |:-|:-|
# |![puyo004.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo004.png)|![puyo005.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo005.png) この形が普通に強そう|
# |![puyo006.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo006.png)|DT砲を見据える．ただ紫も分散してしまうのでその先辛そう|
# |![puyo007.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo007.png)|7手目が1列縦置きだったら見通しよさそう|

# %% [markdown]
# - 11手目(と次の緑ダブ1列目縦置き) がこの試合で最も悪手だったと思う
#     - 3段目に2連結が残ってしまう形は新GTRの受けの広さが死んでキーぷよも2つ必要になって弱いので「クソ雑魚新GTR」と勝手に呼んでいる
#     - 10手目の緑赤を折り返し側においていればまだ挽回できそうだったが，赤の連鎖尾を5連結にするのに夢中で4列目に置いている
#     - 絶対にダメと思っているのに組んでしまっている...
# ![image006.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image006.png)
#
# |置き方例|こっちのほうがいいと思う理由|
# |:-|:-|
# |![puyo008.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo008.png)|![puyo009.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo009.png)赤L字は左向きのほうが多重につながりやすい|
# |![puyo010.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo010.png)|10手目が1列目に置けていれば最低でもL字が組めて無駄が少なそう|
# |![puyo011.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo011.png)|(自分はあまり組まないが)赤を逆L字にするとさらに受けが広くなりそう|

# %% [markdown]
# - 17手目は緑の掃除もかねて2連鎖でけん制...のつもりで打ったが段差がずれて消えず，より扱いづらい感じに
# ![image007.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image007.png)

# %% [markdown]
# - 24手目の赤青1列目縦置きで折り返しが詰み状態になってしまう
#     - クソ雑魚新GTRがキーぷよ2つ必要という不便な点がここで効いてくる
#     - 「2個必要」ということは念頭に入れていたはずだが，とっさの判断ミスで赤青を置いてしまう
#     - とはいえ，これは判断ミスよりも土台構築のほうが問題だと思う
# ![image009.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image009.png)

# %% [markdown]
# - 26手目の時点で「詰んだ」ということに気づき，どうしようとカサカサ...
#     - とりあえず整理しよう，と3連鎖
# ![image010.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image010.png)
# - これにより多少は手が付けられる形に戻ったが，

# %% [markdown]
# - 27手目で緑をちぎってしまい，連鎖に最低でも緑2つ + 青3つが必要な状態．
# ![image011.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/image011.png)
# - その後も以下の通りミスの連発
#     - 自分のフィールドをよく見ていないせいで赤の単発が起こり時間ロス
#     - 待望の青3つも置き場所を間違える
#     - ネクストの青緑さえあれば発火できているのに赤緑を3列目に置いてしまい発火点を失う

# %% [markdown]
# #### 思考時間が十分にあるならどこに置いていたか，とこぷよ形式でシミュレーション
# - 試合中のツモでとこぷよをしてみる
#
# |1~12手目|13~24手目|25~36手目|
# |:-|:-|:-|
# |![puyo012.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo012.png)|![puyo013.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo013.png)|![puyo014.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo014.png)|
#
# - 考えること
#     - ネクネクは見れない(ネクストまで確認して置く)というルール
#     - 相手のけん制，本線に対して対抗できることが目標
#     - ちぎりは一旦あまり気にしない

# %% [markdown]
# - 3手目までは問題なし
# ![puyo015.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo015.png)
#
#
# - 4手目の置き方は1列目以外にもいろいろありそう
#
# |置き方例|いいと思う理由|
# |:-|:-|
# |![puyo016.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo016.png)|![puyo019.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo019.png)連鎖尾の理想形を見据える．折り返し側をフリーにしておく|
# |![puyo017.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo017.png)|![puyo020.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo020.png)不機嫌GTRを目指す|
# |![puyo018.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo018.png)|![puyo021.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo021.png)1列目をフリーにしておく|
#
# - 実際の自習中はそれぞれ試してどれがよさそうか考える
#     - 今回はとりあえず，1つ目の形で試してみる

# %% [markdown]
# - 12手目まで手なりで進める
#     - プレイ時よりは連鎖尾側の見通しがだいぶ良くなって，折り返し側もフリーな状態を保てている
#
# |とこぷよ12手目|プレイ時12手目|
# |:-|:-|
# |![puyo022.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo022.png)|![puyo023.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo023.png)|

# %% [markdown]
# - 13手目はいくつかよさそうな手がある
#
# |置き方例|いいと思う理由|
# |:-|:-|
# |![puyo024.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo024.png)|連鎖尾の完成を目指す|
# |![puyo025.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo025.png)|高さをそろえるために，折り返し側の構築を進める|
#
# - ネクストに青があるため，1列目の青の活用を狙って今回は一旦連鎖尾側に置く

# %% [markdown]
# - 手なりで進めてみると，何やら苦しい感じになってきた
#     - 発火点が紫1色しかない．余分な紫をツモってしまっていることもあり，肝心な時に発火できない可能性も...
#     - 色の摩擦が大きく，伸ばしづらい．第二折りを見据えた連鎖尾の赤緑も，紫がL字になってる & 赤がなかなか来ないせいで第二折りにならない
#
# ![puyo026.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo026.png)
#
# |多色発火目指すならこんな感じ？|6列目を14手目まで粘り，連鎖尾の理想形にこだわる？|
# |:-|:-|
# |![puyo027.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo027.png)|![puyo028.png](https://raw.githubusercontent.com/TetsuyaKomota/HOBBY_puyo/master/note/images/puyo028.png)|

# %% [markdown]
# - こんな感じで，納得いくまで以下を繰り返す
#     - いくつかよさそうなのあるな，と思ったらそれぞれ試してみる
#     - 途中で微妙に感じたら少し戻して考える
